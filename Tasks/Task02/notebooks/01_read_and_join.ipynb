# %%
import pandas as pd
from sqlalchemy import create_engine, inspect

DB_URL = "postgresql+psycopg2://postgres:postgres@localhost:5432/olist"

engine = create_engine(DB_URL)

# Test the connection
with engine.connect() as connection:
    print("Connected to PostgreSQL successfully!")
# Out:
# Connected to PostgreSQL successfully!

# %%
inspector = inspect(engine)

tables = inspector.get_table_names()

print("Tables:")
for table in tables:
    print(table)
# Out:
# Tables:
# olist_sellers
# product_category_name_translation
# olist_orders
# olist_order_items
# olist_customers
# olist_geolocation
# olist_order_payments
# olist_order_reviews
# olist_products

# %%
data = {}

for table in tables:
    data[table] = pd.read_sql_table(table, engine)
    
    print(f"{table}: {data[table].shape}")
# Out:
# olist_sellers: (3095, 4)
# product_category_name_translation: (71, 2)
# olist_orders: (99441, 8)
# olist_order_items: (112650, 7)
# olist_customers: (99441, 5)
# olist_geolocation: (1000163, 5)
# olist_order_payments: (103886, 5)
# olist_order_reviews: (99224, 7)
# olist_products: (32951, 9)

# %%
for table, df in data.items():
    print("=" * 60)
    print(f"TABLE: {table}")
    print(f"Rows: {len(df):,}")
    print(f"Columns: {len(df.columns)}")
    print("Columns:", df.columns.tolist())
    display(df.head(3))
# Out:
# ...
# TABLE: olist_sellers
# Rows: 3,095
# Columns: 4
# Columns: ['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state']
#                           seller_id  seller_zip_code_prefix     seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023        campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844      mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031  rio de janeiro
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
# ...
# TABLE: product_category_name_translation
# Rows: 71
# Columns: 2
# Columns: ['product_category_name', 'product_category_name_english']
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# ...
# TABLE: olist_orders
# Rows: 99,441
# Columns: 8
# ...

# %% [markdown]
# # Check keys and duplicates

# %%
orders = data["olist_orders"]

print("Orders:", len(orders))
print("Unique order_id:", orders["order_id"].nunique())
print("Duplicate order_id:", orders["order_id"].duplicated().sum())
# Out:
# Orders: 99441
# Unique order_id: 99441
# Duplicate order_id: 0

# %%
customers = data["olist_customers"]

print("Customers:", len(customers))
print("Unique customer_id:", customers["customer_id"].nunique())
print("Duplicate customer_id:", customers["customer_id"].duplicated().sum())
# Out:
# Customers: 99441
# Unique customer_id: 99441
# Duplicate customer_id: 0

# %%
order_items = data["olist_order_items"]

print("Order items:", len(order_items))
print("Unique order_id:", order_items["order_id"].nunique())
print("Rows per order:")
display(order_items.groupby("order_id").size().value_counts().sort_index().head())
# Out:
# Order items: 112650
# Unique order_id: 98666
# Rows per order:
# 1    88863
# 2     7516
# 3     1322
# 4      505
# 5      204
# Name: count, dtype: int64

# %%
payments = data["olist_order_payments"]

print("Payments:", len(payments))
print("Unique order_id:", payments["order_id"].nunique())
print("Rows per order:")
display(payments.groupby("order_id").size().value_counts().sort_index().head())
# Out:
# Payments: 103886
# Unique order_id: 99440
# Rows per order:
# 1    96479
# 2     2382
# 3      301
# 4      108
# 5       52
# Name: count, dtype: int64

# %%
products = data["olist_products"]

print("Products:", len(products))
print("Unique product_id:", products["product_id"].nunique())
print("Duplicate product_id:", products["product_id"].duplicated().sum())
# Out:
# Products: 32951
# Unique product_id: 32951
# Duplicate product_id: 0

# %%
sellers = data["olist_sellers"]

print("Sellers:", len(sellers))
print("Unique seller_id:", sellers["seller_id"].nunique())
print("Duplicate seller_id:", sellers["seller_id"].duplicated().sum())
# Out:
# Sellers: 3095
# Unique seller_id: 3095
# Duplicate seller_id: 0

# %%
for table in ["olist_order_reviews", "olist_geolocation", "product_category_name_translation"]:
    df = data[table]
    
    print("=" * 60)
    print(table)
    print("Rows:", len(df))
    print("Columns:", df.columns.tolist())
    print(df.head(2))
# Out:
# ...
# olist_order_reviews
# Rows: 99224
# Columns: ['review_id', 'order_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp']
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
#
#    review_score review_comment_title review_comment_message  \
# 0             4                 None                   None
# 1             5                 None                   None
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# ...
# olist_geolocation
# Rows: 1000163
# Columns: ['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state']
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# ...

# %% [markdown]
# # build the ML table

# %%
ml_table = orders.copy()

print("Starting rows:", len(ml_table))
print("Unique orders:", ml_table["order_id"].nunique())
# Out:
# Starting rows: 99441
# Unique orders: 99441

# %% [markdown]
# # Aggregate BEFORE joining

# %%
items_agg = (
    order_items
    .groupby("order_id")
    .agg(
        item_count=("order_item_id", "count"),
        product_count=("product_id", "nunique"),
        seller_count=("seller_id", "nunique"),
        total_price=("price", "sum"),
        total_freight=("freight_value", "sum")
    )
    .reset_index()
)

display(items_agg.head())
# Out:
#                            order_id  item_count  product_count  seller_count  \
# 0  00010242fe8c5a6d1ba2dd792cb16214           1              1             1
# 1  00018f77f2f0320c557190d7a144bdd3           1              1             1
# 2  000229ec398224ef6ca0657da4fc703e           1              1             1
# 3  00024acbcdf0a6daa1e931b038114c75           1              1             1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9           1              1             1
#
#    total_price  total_freight
# 0        58.90          13.29
# 1       239.90          19.93
# 2       199.00          17.87
# 3        12.99          12.79
# 4       199.90          18.14

# %%
payments_agg = (
    payments
    .groupby("order_id")
    .agg(
        payment_count=("payment_sequential", "count"),
        payment_value=("payment_value", "sum"),
        max_installments=("payment_installments", "max")
    )
    .reset_index()
)

display(payments_agg.head())
# Out:
#                            order_id  payment_count  payment_value  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1          72.19
# 1  00018f77f2f0320c557190d7a144bdd3              1         259.83
# 2  000229ec398224ef6ca0657da4fc703e              1         216.87
# 3  00024acbcdf0a6daa1e931b038114c75              1          25.78
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1         218.04
#
#    max_installments
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 3

# %% [markdown]
# # Join

# %%
customer_info = customers[
    [
        "customer_id",
        "customer_unique_id",
        "customer_city",
        "customer_state"
    ]
]

ml_table = ml_table.merge(
    customer_info,
    on="customer_id",
    how="left",
    validate="many_to_one"
)

print(ml_table.shape)
# Out:
# (99441, 11)

# %%
ml_table = ml_table.merge(
    items_agg,
    on="order_id",
    how="left",
    validate="one_to_one"
)

print(ml_table.shape)
# Out:
# (99441, 16)

# %%
ml_table = ml_table.merge(
    payments_agg,
    on="order_id",
    how="left",
    validate="one_to_one"
)

print(ml_table.shape)
# Out:
# (99441, 19)

# %% [markdown]
# # Validate

# %%
print("Rows:", len(ml_table))
print("Unique orders:", ml_table["order_id"].nunique())
print("Duplicate orders:", ml_table["order_id"].duplicated().sum())
# Out:
# Rows: 99441
# Unique orders: 99441
# Duplicate orders: 0

# %%
assert ml_table["order_id"].is_unique

print("ML table contains exactly one row per order")
# Out:
# ML table contains exactly one row per order

# %%
print("Final shape:", ml_table.shape)

display(ml_table.head())

print("\nMissing values:")
display(ml_table.isna().sum().sort_values(ascending=False).head(10))
# Out:
# Final shape: (99441, 19)
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# # Save the artifact

# %%
ml_table.to_parquet(
    "../artifacts/ml_table.parquet",
    index=False
)

print("ml_table.parquet saved")
# Out:
# ml_table.parquet saved

# %%
saved = pd.read_parquet("../artifacts/ml_table.parquet")

assert saved["order_id"].is_unique

print("Artifact verified")
print("Shape:", saved.shape)
print("Rows:", len(saved))
print("Unique orders:", saved["order_id"].nunique())
print("Duplicate orders:", saved["order_id"].duplicated().sum())
# Out:
# Artifact verified
# Shape: (99441, 19)
# Rows: 99441
# Unique orders: 99441
# Duplicate orders: 0

# %% [markdown]
# ## Notebook 1 Summary
#
# The database tables were inspected individually to understand their row meaning,
# keys, and relationships.
#
# The `olist_orders` table was used as the base table because each row represents one order.
#
# The `olist_order_items` and `olist_order_payments` tables contain multiple rows per order,
# so they were aggregated to the order level before joining.
#
# Customer information was joined using `customer_id`.
#
# The final ML table contains exactly one row per order and was saved as:
#
# `../artifacts/ml_table.parquet`
